# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# D:\NexaBiz\ai\venv\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
vocabulary = ["green", "leaves", "demand", "forecast"]

# %%
def fix_spelling(query, words):
    best_match = process.extractOne(query, words)
    if best_match[1] > 80: #threshold
        return best_match[0]
    return query

# %%
def get_suggestions(query, words):
    matches = process.extract(query, words, limit=5)
    return [m[0] for m in matches if m[1] > 70]

# %%
query = "leavs"  # Test with a typo
fixed = fix_spelling(query, vocabulary)
suggestions = get_suggestions(query, vocabulary)
print("Fixed:", fixed)
print("Suggestions:", suggestions)
# Out:
# Fixed: leaves
# Suggestions: ['leaves']
